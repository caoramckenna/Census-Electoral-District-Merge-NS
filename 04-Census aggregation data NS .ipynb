# %%
#load libraries
import pandas as pd

# %%
# load tract/ subdivision to electoral district lookup
shapes = pd.read_csv("NS_tractsubdivision_to_electoraldistrict_portions.csv",dtype={"tract": str})

# %%
len(shapes)
# Out:
# 141

# %%
shapes.head()
# Out:
#      prov_name_fr_1             Census_subdivision    prov_name_fr_2  \
# 0  Nouvelle-Ãcosse                        Amherst  Nouvelle-Ãcosse
# 1  Nouvelle-Ãcosse                Annapolis Royal  Nouvelle-Ãcosse
# 2  Nouvelle-Ãcosse  Annapolis Valley First Nation  Nouvelle-Ãcosse
# 3  Nouvelle-Ãcosse             Annapolis, Subd. A  Nouvelle-Ãcosse
# 4  Nouvelle-Ãcosse             Annapolis, Subd. B  Nouvelle-Ãcosse
#
#        Electoral_district          area      prov_name_fr  total_tract_area  \
# 0  Cumberland--Colchester  9.106538e+06  Nouvelle-Ãcosse      9.106538e+06
# 1              Nova-Ouest  1.461314e+06  Nouvelle-Ãcosse      1.461314e+06
# 2            Kings--Hants  6.776597e+05  Nouvelle-Ãcosse      6.776597e+05
# 3              Nova-Ouest  6.378984e+08  Nouvelle-Ãcosse      8.258252e+08
# 4              Nova-Ouest  3.847291e+08  Nouvelle-Ãcosse      4.551965e+08
#
#    tract_percent
# 0       1.000000
# 1       1.000000
# 2       1.000000
# 3       0.772438
# ...

# %%
# bring TK data in for NS from 2021 census
TK = pd.read_csv("98-401-X2021018_English_CSV_data.csv",dtype={"tract": str}, encoding='latin-1')

# %%
TK.head(20)
# Out:
#     CENSUS_YEAR             DGUID  ALT_GEO_CODE           GEO_LEVEL  \
# 0          2021  2021A00051201001       1201001  Census subdivision
# 1          2021  2021A00051201001       1201001  Census subdivision
# 2          2021  2021A00051201001       1201001  Census subdivision
# 3          2021  2021A00051201001       1201001  Census subdivision
# 4          2021  2021A00051201001       1201001  Census subdivision
# 5          2021  2021A00051201001       1201001  Census subdivision
# 6          2021  2021A00051201001       1201001  Census subdivision
# 7          2021  2021A00051201001       1201001  Census subdivision
# 8          2021  2021A00051201001       1201001  Census subdivision
# 9          2021  2021A00051201001       1201001  Census subdivision
# 10         2021  2021A00051201001       1201001  Census subdivision
# 11         2021  2021A00051201001       1201001  Census subdivision
# 12         2021  2021A00051201001       1201001  Census subdivision
# ...
